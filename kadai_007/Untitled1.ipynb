# %%
import matplotlib.pyplot as plt
import pandas as pd
# !pip install japanize-matplotlib
import japanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 30.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for japanize-matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=73333a7697381bd29e3c1435956382e4a075c8519d623ace08b2df9ddc754d19
#   Stored in directory: /root/.cache/pip/wheels/da/a1/71/b8faeb93276fed10edffcca20746f1ef6f8d9e071eee8425fc
# Successfully built japanize-matplotlib
# ...

# %%
df =pd.read_csv("/content/sample_pandas_6.csv")
category_df = pd.read_csv('/content/category.csv')
category_df
df = pd.merge(df, category_df[['商品番号', 'カテゴリー']], how='inner', on='商品番号')
df['カテゴリー'].value_counts()
plt.bar(df['カテゴリー'].value_counts().index, df['カテゴリー'].value_counts())
plt.show()
df.groupby('商品番号')['カテゴリー'].value_counts()
df.groupby('商品番号')['カテゴリー'].describe()
# Out:
#          count unique    top freq
# 商品番号
# 1QJFO8QY    32      1     弁当   32
# 2HSTCDWM    20      1   デザート   20
# 48XMJXKO    10      1   デザート   10
# 8T7D5DQA    21      1    菓子類   21
# MESUDVWQ    17      1    菓子類   17
# QRMOGNUU    27      1     雑貨   27
# S6RE8W6X    20      1  図書・新聞   20
# X0ZE2ZMY    14      1    飲料水   14
# YY4HAAZR    17      1     弁当   17
# Z4WOOIYV    22      1    飲料水   22
